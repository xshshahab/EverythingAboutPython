# %% [markdown]
# # 🐍 Python Data Types
#
# In Python, **data types** specify the kind of value a variable holds. Python is **dynamically typed**, meaning you don't need to declare a variable's type — Python figures it out at runtime.
#
# ---
#
# ## 📦 Built-in Data Types
#
# ### 1. Numeric Types
#
# - `int` – Integer numbers
# - `float` – Decimal numbers
# - `complex` – Complex numbers
#
# ```python
# x = 10        # int
# y = 3.14      # float
# z = 2 + 3j    # complex
# ```
#
# ---
#
# ### 2. Text Type
#
# - `str` – String (sequence of characters)
#
# ```python
# name = "Python is awesome"
# ```
#
# ---
#
# ### 3. Boolean Type
#
# - `bool` – Boolean values: `True` or `False`
#
# ```python
# is_active = True
# is_admin = False
# ```
#
# ---
#
# ### 4. Sequence Types
#
# - `list` – Ordered, mutable sequence
# - `tuple` – Ordered, immutable sequence
# - `range` – Immutable sequence of numbers
#
# ```python
# fruits = ["apple", "banana", "cherry"]  # list
# coordinates = (10, 20)                  # tuple
# numbers = range(5)                      # range(0, 5)
# ```
#
# ---
#
# ### 5. Mapping Type
#
# - `dict` – Collection of key-value pairs
#
# ```python
# person = {
#     "name": "Alice",
#     "age": 30
# }
# ```
#
# ---
#
# ### 6. Set Types
#
# - `set` – Unordered, unique items
# - `frozenset` – Immutable set
#
# ```python
# colors = {"red", "green", "blue"}        # set
# frozen_colors = frozenset(["red", "green"])
# ```
#
# ---
#
# ### 7. None Type
#
# - `NoneType` – Represents the absence of a value
#
# ```python
# result = None
# ```
#
# ---
#
# ## 🔍 Check Data Type
#
# Use `type()` to check the data type of any variable:
#
# ```python
# print(type(10))         # <class 'int'>
# print(type("hello"))    # <class 'str'>
# print(type([1, 2, 3]))   # <class 'list'>
# ```
